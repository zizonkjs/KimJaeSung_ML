# %% [markdown]
# #####  알파벳 기반 언어 식별 모델
# - 데이터셋 : lang.zip사용해서 생성 -> csv, json ,...
# - 학습방법 : 지도학습 > 분류 - 다중분류
# - 알고리즘 : 다양하게

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈로딩
import pandas as pd             
import os
from collections import Counter

# %%
# 데이터 파일
TRAIN_PATH = '../data/train/'
TEST_PATH = '../data/test/'

TRAIN_CSV = '../data/lang_train.csv'
TEST_CSV = '../data/lang_test.csv'

# %%
# 파일 읽기 => open() -> read(), readline(), readlines() -> close() 
#          => with open() as 구문

if not os.path.exists(TRAIN_CSV):
    print(f'{TRAIN_CSV} 파일이 없습니다.')
else:
    with open(TRAIN_CSV, mode='r') as f: 
        alldata=f.read()
        print(f'[File Data] {alldata}' )
# Out:
# ../data/lang_train.csv 파일이 없습니다.

# %%
# 폴더 안에 파일 및 폴더 을 가져오기
files=os.listdir(TRAIN_PATH)

for file in files:
    print(file, TRAIN_PATH+file, os.path.exists(TRAIN_PATH+file))
    label=file[:2]
    print(f'Label => {label}')
    
    with open(TRAIN_PATH+file, mode='r') as f: 
         alldata=f.read()
     
    #- 대소문자 통일
    alldata=alldata.lower()
    
    #- 알파벳 아닌 문자들 제거
    alldata=alldata.replace('\n', '')
    print(f'alldata => {len(alldata)}')
    
    for ch in alldata:
         if ord('a')> ord(ch) or ord(ch)> ord('z'): 
              alldata=alldata.replace(ch, '')
    print(f'alldata => {len(alldata)}')
    
    with open(TRAIN_CSV ,mode='a') as f:
     # - a ~ z 개수 카운팅  ==> 정렬, 전체 단어수로 나누기 
     a_z=[]
     for _ in range(ord('a'), ord('z')+1):
          cnt = alldata.count(chr(_))
          a_z.append(str(cnt/len(alldata)))
          
     f.write(label+',')
     f.write(','.join( a_z )+'\n')
# Out:
# en-1.txt ../data/train/en-1.txt True
# Label => en
# alldata => 5358
# alldata => 4595
# en-2.txt ../data/train/en-2.txt True
# Label => en
# alldata => 10782
# alldata => 8387
# en-3.txt ../data/train/en-3.txt True
# Label => en
# alldata => 4397
# alldata => 3615
# en-4.txt ../data/train/en-4.txt True
# Label => en
# alldata => 6815
# alldata => 5304
# en-5.txt ../data/train/en-5.txt True
# Label => en
# alldata => 6146
# alldata => 4566
# fr-10.txt ../data/train/fr-10.txt True
# Label => fr
# alldata => 21300
# alldata => 15596
# fr-6.txt ../data/train/fr-6.txt True
# Label => fr
# alldata => 36732
# alldata => 27749
# fr-7.txt ../data/train/fr-7.txt True
# Label => fr
# alldata => 22105
# alldata => 16915
# fr-8.txt ../data/train/fr-8.txt True
# Label => fr
# alldata => 11142
# alldata => 8058
# fr-9.txt ../data/train/fr-9.txt True
# Label => fr
# alldata => 7016
# alldata => 5130
# id-11.txt ../data/train/id-11.txt True
# Label => id
# alldata => 2634
# alldata => 2007
# id-12.txt ../data/train/id-12.txt True
# Label => id
# alldata => 9938
# alldata => 7936
# id-13.txt ../data/train/id-13.txt True
# Label => id
# alldata => 30287
# alldata => 25451
# id-14.txt ../data/train/id-14.txt True
# Label => id
# alldata => 17324
# alldata => 14905
# id-15.txt ../data/train/id-15.txt True
# Label => id
# alldata => 78297
# alldata => 61604
# tl-16.txt ../data/train/tl-16.txt True
# Label => tl
# alldata => 34630
# alldata => 27338
# tl-17.txt ../data/train/tl-17.txt True
# Label => tl
# alldata => 40515
# alldata => 32871
# tl-18.txt ../data/train/tl-18.txt True
# Label => tl
# alldata => 22366
# alldata => 17848
# tl-19.txt ../data/train/tl-19.txt True
# Label => tl
# alldata => 15555
# alldata => 11568
# tl-20.txt ../data/train/tl-20.txt True
# Label => tl
# alldata => 9000
# alldata => 7259

# %%
def make_dataset(dir_path, file_path):
    files=os.listdir(dir_path)

    for file in files:
        label=file[:2]
        
        with open(dir_path+file, mode='r') as f: 
            alldata=f.read()
        
        #- 대소문자 통일
        alldata=alldata.lower()
        
        #- 알파벳 아닌 문자들 제거
        alldata=alldata.replace('\n', '')
        print(f'alldata => {len(alldata)}')
        
        for ch in alldata:
            if ord('a')> ord(ch) or ord(ch)> ord('z'): 
                alldata=alldata.replace(ch, '')
        print(f'alldata => {len(alldata)}')
        
        with open(file_path ,mode='a') as f:
            # - a ~ z 개수 카운팅  ==> 정렬, 전체 단어수로 나누기 
            a_z=[]
            for _ in range(ord('a'), ord('z')+1):
                cnt = alldata.count(chr(_))
                a_z.append(str(cnt/len(alldata)))
                
            f.write(label+',')
            f.write(','.join( a_z )+'\n')

# %%
make_dataset(TRAIN_PATH, TRAIN_CSV)
make_dataset(TEST_PATH, TEST_CSV)
# Out:
# alldata => 5358
# alldata => 4595
# alldata => 10782
# alldata => 8387
# alldata => 4397
# alldata => 3615
# alldata => 6815
# alldata => 5304
# alldata => 6146
# alldata => 4566
# alldata => 21300
# alldata => 15596
# alldata => 36732
# alldata => 27749
# alldata => 22105
# alldata => 16915
# alldata => 11142
# alldata => 8058
# alldata => 7016
# alldata => 5130
# alldata => 2634
# alldata => 2007
# alldata => 9938
# alldata => 7936
# alldata => 30287
# alldata => 25451
# alldata => 17324
# alldata => 14905
# alldata => 78297
# alldata => 61604
# alldata => 34630
# alldata => 27338
# alldata => 40515
# alldata => 32871
# alldata => 22366
# alldata => 17848
# alldata => 15555
# alldata => 11568
# alldata => 9000
# alldata => 7259
# alldata => 59001
# alldata => 45619
# alldata => 139001
# alldata => 101952
# alldata => 35425
# alldata => 26566
# alldata => 63459
# alldata => 45301
# alldata => 7930
# alldata => 6154
# alldata => 33000
# alldata => 25641
# alldata => 33673
# alldata => 26235
# alldata => 2052
# alldata => 1652

# %%
col_names=[]
trainDF=pd.read_csv(TRAIN_CSV, header=None)
trainDF
# Out:
#     0         1         2         3         4         5         6         7   \
# 0   en  0.075952  0.012840  0.045702  0.046137  0.105332  0.015669  0.019151
# 1   en  0.084178  0.019912  0.030404  0.038870  0.136998  0.017408  0.031239
